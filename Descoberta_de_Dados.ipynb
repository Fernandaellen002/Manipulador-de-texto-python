# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernandaellen002/Manipulador-de-texto-python/blob/main/Descoberta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Carregar os dados
#
# ### Subtask:
# Carregar o arquivo CSV em um DataFrame pandas.

# %% [markdown]
# **Reasoning**:
# The previous attempt to load the data failed because the file was not found. The instruction specifies the correct path to the CSV file. I will use this path to load the data into a pandas DataFrame.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("/content/sample_data/best_selling_switch_games.csv")

# %% [markdown]
# **Reasoning**:
# The subtask was to load the CSV file into a pandas DataFrame. The previous code block successfully loaded the data. Now I will display the first few rows and the info of the dataframe to verify the loading was successful.

# %%
# Display the first few rows
display(df.head())

# Display information about the DataFrame
display(df.info())
# Out:
#                                      title  copies_sold              genre  \
# 0                      Mario Kart 8 Deluxe   48410000.0        Kart racing
# 1            Animal Crossing: New Horizons   40170000.0  Social simulation
# 2               Super Smash Bros. Ultimate   29530000.0           Fighting
# 3  The Legend of Zelda: Breath of the Wild   27790000.0   Action-adventure
# 4                 Pokémon Sword and Shield   25370000.0       Role-playing
#
#                        developer                    publisher       as_of  \
# 0                   Nintendo EPD                     Nintendo  2022-09-30
# 1                   Nintendo EPD                     Nintendo  2022-09-30
# 2  Bandai Namco StudiosSora Ltd.                     Nintendo  2022-09-30
# 3                   Nintendo EPD                     Nintendo  2022-09-30
# 4                     Game Freak  The Pokémon CompanyNintendo  2022-09-30
#
#   release_date
# 0   2017-04-28
# 1   2020-03-20
# 2   2018-12-07
# ...

# %% [markdown]
# ## Análise exploratória inicial
#
# ### Subtask:
# Exibir as primeiras linhas, informações gerais e estatísticas descritivas do DataFrame para entender a estrutura e o conteúdo dos dados.

# %% [markdown]
# **Reasoning**:
# Display the first few rows, general information, and descriptive statistics of the DataFrame as requested by the subtask.

# %%
# Primeiras linhas
print("🔹 Primeiras linhas:")
display(df.head())

# Informações da base
print("\n🔹 Informações da base:")
print(df.info())

# Estatísticas resumidas (só colunas numéricas)
print("\n🔹 Estatísticas resumidas:")
print(df.describe())
# Out:
# 🔹 Primeiras linhas:
#                                      title  copies_sold              genre  \
# 0                      Mario Kart 8 Deluxe   48410000.0        Kart racing
# 1            Animal Crossing: New Horizons   40170000.0  Social simulation
# 2               Super Smash Bros. Ultimate   29530000.0           Fighting
# 3  The Legend of Zelda: Breath of the Wild   27790000.0   Action-adventure
# 4                 Pokémon Sword and Shield   25370000.0       Role-playing
#
#                        developer                    publisher       as_of  \
# 0                   Nintendo EPD                     Nintendo  2022-09-30
# 1                   Nintendo EPD                     Nintendo  2022-09-30
# 2  Bandai Namco StudiosSora Ltd.                     Nintendo  2022-09-30
# 3                   Nintendo EPD                     Nintendo  2022-09-30
# 4                     Game Freak  The Pokémon CompanyNintendo  2022-09-30
#
#   release_date
# 0   2017-04-28
# ...

# %% [markdown]
# ## Tratamento de dados ausentes
#
# ### Subtask:
# Verificar e tratar quaisquer valores nulos, se necessário.

# %% [markdown]
# **Reasoning**:
# Check for null values in the DataFrame and print the result to confirm the initial observation from the exploratory analysis.

# %%
# Verificar valores nulos
print("\n🔹 Valores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# 🔹 Valores ausentes por coluna:
# title           0
# copies_sold     0
# genre           0
# developer       0
# publisher       0
# as_of           0
# release_date    0
# dtype: int64

# %% [markdown]
# ## Visualização de dados
#
# ### Subtask:
# Gerar gráficos relevantes (por exemplo, vendas por gênero, editora, ano de lançamento, etc.) para identificar tendências e padrões.

# %% [markdown]
# **Reasoning**:
# Generate the requested plots to visualize sales by genre, publisher, and release year, incorporating necessary data transformations for the release date.

# %%
# 2. Gráfico de barras para cópias vendidas por gênero
genre_sales = df.groupby('genre')['copies_sold'].sum().sort_values(ascending=False).head(10) # Limit to top 10 genres for clarity
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_sales.index, y=genre_sales.values, palette='viridis')
plt.title('Top 10 Cópias Vendidas por Gênero', fontsize=14)
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Cópias Vendidas', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 3. Gráfico de barras para cópias vendidas pelas principais editoras
publisher_sales = df.groupby('publisher')['copies_sold'].sum().sort_values(ascending=False).head(10) # Limit to top 10 publishers for clarity
plt.figure(figsize=(12, 6))
sns.barplot(x=publisher_sales.index, y=publisher_sales.values, palette='viridis')
plt.title('Top 10 Cópias Vendidas por Editora', fontsize=14)
plt.xlabel('Editora', fontsize=12)
plt.ylabel('Cópias Vendidas', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 4. Gráfico de dispersão para relação entre ano de lançamento e cópias vendidas
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_year'] = df['release_date'].dt.year

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['release_year'], y=df['copies_sold'], alpha=0.6)
plt.title('Relação entre Ano de Lançamento e Cópias Vendidas', fontsize=14)
plt.xlabel('Ano de Lançamento', fontsize=12)
plt.ylabel('Cópias Vendidas', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-286298410.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_sales.index, y=genre_sales.values, palette='viridis')
# /tmp/ipython-input-286298410.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_sales.index, y=publisher_sales.values, palette='viridis')
# /tmp/ipython-input-286298410.py:20: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Análise e insights
#
# ### Subtask:
# Interpretar os resultados da análise exploratória e das visualizações para extrair insights significativos sobre os jogos mais vendidos do Switch.

# %% [markdown]
# ## Conclusões e aplicações
#
# ### Subtask:
# Resumir as principais descobertas e discutir como esses insights podem ser aplicados (por exemplo, para estratégias de marketing, desenvolvimento de jogos, etc.).

# %% [markdown]
# **Reasoning**:
# Summarize the key findings and discuss their implications and potential applications for the gaming industry.

# %%
# 1. Listar os principais insights obtidos
print("### Principais Insights:")
print("- Gêneros Dominantes: RPG, Platformer e Action-adventure lideram em cópias vendidas.")
print("- Domínio da Editora Nintendo: A Nintendo é a editora com o maior volume de vendas, muito à frente das demais.")
print("- Influência do Ano de Lançamento: Jogos lançados nos primeiros anos do console (2017-2019) representam uma parcela significativa dos jogos mais vendidos.")
print("- Longevidade das Vendas: Jogos lançados em anos anteriores continuam vendendo bem, indicando um ciclo de vida longo para títulos populares no Switch.")

# 2. Descrever as implicações e aplicações dos insights
print("\n### Implicações e Aplicações:")

print("\n**Para Estratégias de Marketing:**")
print("- Foco em Gêneros Populares: Campanhas de marketing devem priorizar RPGs, jogos de Plataforma e Action-adventure, destacando suas características que atraem a base de jogadores do Switch.")
print("- Alavancagem da Marca Nintendo: Editoras third-party podem buscar parcerias ou destacar a compatibilidade com o ecossistema Nintendo em suas promoções.")
print("- Promoção de Catálogo Antigo: Investir em marketing contínuo para títulos populares lançados em anos anteriores pode manter as vendas a longo prazo.")

print("\n**Para Decisões de Desenvolvimento de Jogos:**")
print("- Priorização de Gêneros de Sucesso: Estudar os elementos que tornam os jogos de RPG, Plataforma e Action-adventure no Switch tão populares para informar o desenvolvimento de novos títulos nesses gêneros.")
print("- Identificação de Nichos: Embora os gêneros populares dominem, analisar os dados de vendas de outros gêneros (mesmo que menores em volume total) pode revelar nichos de mercado lucrativos a serem explorados.")
print("- Otimização para a Plataforma Switch: Considerar as características únicas do hardware e do público do Switch ao desenvolver jogos para maximizar o potencial de vendas.")

print("\n**Para Planejamento de Lançamentos:**")
print("- Considerar o Ciclo de Vida: Planejar o marketing e o suporte pós-lançamento com uma perspectiva de longo prazo, dado o histórico de vendas sustentadas no Switch.")
print("- Sazonalidade e Concorrência: Embora não diretamente visível nos gráficos de ano de lançamento, considerar a sazonalidade (ex: feriados) e os lançamentos de jogos concorrentes ao definir datas de lançamento.")

# 3. Considerar outros fatores e ressalvas
print("\n### Outros Fatores e Considerações (Ressalvas):")
print("- Força das Franquias: Muitos dos jogos mais vendidos pertencem a franquias estabelecidas (Mario, Zelda, Pokémon), o que impacta significativamente as vendas e não é explicitamente detalhado na base.")
print("- Exclusividade da Plataforma: A exclusividade de muitos títulos da Nintendo é um fator crucial para o sucesso de vendas no Switch e não está representada nos dados brutos.")
print("- Fatores de Qualidade e Crítica: A qualidade percebida do jogo (avaliações da crítica e dos jogadores) influencia as vendas, mas não está presente na base de dados.")
print("- Marketing e Distribuição da Editora: A força do marketing e dos canais de distribuição de uma editora (além da Nintendo) também desempenha um papel importante.")
print("- Dados de Vendas Mundiais vs. Regionais: A base de dados provavelmente representa vendas globais; análises regionais podem revelar padrões diferentes.")
# Out:
# ### Principais Insights:
# - Gêneros Dominantes: RPG, Platformer e Action-adventure lideram em cópias vendidas.
# - Domínio da Editora Nintendo: A Nintendo é a editora com o maior volume de vendas, muito à frente das demais.
# - Influência do Ano de Lançamento: Jogos lançados nos primeiros anos do console (2017-2019) representam uma parcela significativa dos jogos mais vendidos.
# - Longevidade das Vendas: Jogos lançados em anos anteriores continuam vendendo bem, indicando um ciclo de vida longo para títulos populares no Switch.
#
# ### Implicações e Aplicações:
#
# **Para Estratégias de Marketing:**
# - Foco em Gêneros Populares: Campanhas de marketing devem priorizar RPGs, jogos de Plataforma e Action-adventure, destacando suas características que atraem a base de jogadores do Switch.
# - Alavancagem da Marca Nintendo: Editoras third-party podem buscar parcerias ou destacar a compatibilidade com o ecossistema Nintendo em suas promoções.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains information on 73 best-selling Nintendo Switch games.
# *   There are no missing values in the dataset.
# *   The number of copies sold ranges from 1 million to 48.41 million, with an average of approximately 6.79 million.
# *   RPG, Action, and Adventure are the genres with the highest total sales.
# *   Nintendo is the dominant publisher in terms of sales volume.
# *   Games released in the early years of the console (2017-2019) account for a significant portion of the best-selling titles.
# *   Older popular titles continue to sell well, indicating a long sales lifecycle on the Switch.
#
# ### Insights or Next Steps
#
# *   Future game development and marketing efforts could prioritize RPG, Platformer, and Action-adventure genres, given their strong sales performance.
# *   Publishers should consider the long-term sales potential of successful Switch titles and plan for sustained marketing and support.
